# %% [markdown]
# # `문법`
# ### `문단 구분`
# 엔터 한 번 = 의미 없음 ( 출력 시 엔터 없이 이어짐)
#
# 엔터 두 번 = 엔터
#
# 띄어쓰기 한 번 = 띄어쓰기
#
# 띄어쓰기 두 번 = 앞 뒤 특수 문법등을 구별?
# ### `글씨 크기`
# # #
# ## ##
# ### ###
# #### ####
# ##### #####
# ###### ######
# ### `글씨 강조`
# *별로 감쌈*
#
# __언더바 두 개로 감쌈__
#
# ***별 세 개로 감쌈***
#
# ~~물결 두 개로 감쌈~~
#
# `백틱으로 감쌈`
# ### `리스트`
# 리스트는 종류에는 번호가 있는 리스트와, 번호가 없는 리스트가 있다.
#
# 1. First
# 2. Second
# 3. Third
# 5. Fourth
#
# - 얘는 왜? ㅋㅋㅋ
#   - 얘가 아래의 첫 번째랑 같음...
#     - 얘는 두번째랑...
#
#
# - Apple
#   - Orange
#     - Grape
#
# + Apple
#   + Orange
#     + Grape
#
# * Apple
#   * Orange
#     * Grape
#
# - Apple
#   + Orange
#     * Grape
#
# ### `링크`
# <http://google.com/>
#
# <address@example.com>
#
# URL주소랑 이메일주소 요로코롬 쓸 수 있다
#
#
#
# #### 링크 바로 연결도 가능
#
# [구글](http://google.com "타이틀 지정")
#
# #### 참조링크
#
# [likevariable]: http://google.com "Go Goole - Reference Link"
#
#   구글 : [얘가 보여줄 이름][likevariable]
#
# ### `인용문`
# 인용문을 사용할 때는 > 기호를 이용하여 사용한다. 추가로 인용문 안에서는 다른 마크 다운 문법을 사용할 수도 있다.
#
# > This is a block quote
# > ### This is a block quote in header
# >> This is a Double block quote
#
# ### `코드 블록`
#     탭도 된다매..
#
# ```요건 잘 됨```
# `하나로도 됨`
#
# ```javascript
# var test = function() {
#   console.log('test!');
# }
# ```
#
# 추가로 이 글 위에처럼 GitHub 의 Markdown 에서는 코드 블록에 프로그래밍 언어 별로 하이라이트 표시를 사용할 수 있다. 그때는 ｀ 3개 이후 특정 프로그래밍 언어 이름을 선언 후 코드 블록을 시작하면 된다.
#
# ### `수평선`
# ***
#
# ---
#
# ___
#
# 각 줄은 별 세 개 바 세 개 언더바 세 개
#
# ### `이미지?!?!`
# ![대체 텍스트1](/dev/19/chrome.png "Chrome icon")
#
# 암튼 이미지도 할 수 있대...
#
# ### `테이블`
#
# |Left Header|Center Header|Right Header|
# |:----------|:-----------:|-----------:|
# |1번|2번|3번|
#
# ### `체크박스`
# - [x] Checked1
# - [x] Checked2
# - [ ] UnChecked1
# - [ ] UnChecked2
